# %%
import pandas as pd

# %%
scores = pd.read_csv('scores.csv', header = 0)

# %%
scores.head()
# Out:
#   School ID                                        School Name    Borough  \
# 0    02M260                 Clinton School Writers and Artists  Manhattan
# 1    06M211  Inwood Early College for Health and Informatio...  Manhattan
# 2    01M539  New Explorations into Science, Technology and ...  Manhattan
# 3    02M294                               Essex Street Academy  Manhattan
# 4    02M308                       Lower Manhattan Arts Academy  Manhattan
#
#   Building Code        Street Address       City State  Zip Code  Latitude  \
# 0          M933  425 West 33rd Street  Manhattan    NY     10001  40.75321
# 1          M052    650 Academy Street  Manhattan    NY     10002  40.86605
# 2          M022   111 Columbia Street  Manhattan    NY     10002  40.71873
# 3          M445      350 Grand Street  Manhattan    NY     10002  40.71687
# 4          M445      350 Grand Street  Manhattan    NY     10002  40.71687
#
# ...

# %%
scores.describe()
# Out:
#            Zip Code    Latitude   Longitude  Student Enrollment  \
# count    435.000000  435.000000  435.000000          428.000000
# mean   10726.096552   40.745472  -73.921072          702.357477
# std      537.927907    0.080937    0.071705          759.176061
# min    10001.000000   40.528230  -74.192150           62.000000
# 25%    10301.500000   40.690495  -73.979260          357.250000
# 50%    10472.000000   40.741210  -73.925140          466.000000
# 75%    11217.000000   40.822095  -73.882580          623.250000
# max    11694.000000   40.888370  -73.726910         5447.000000
#
#        Average Score (SAT Math)  Average Score (SAT Reading)  \
# count                375.000000                   375.000000
# mean                 432.944000                   424.504000
# std                   71.952373                    61.881069
# min                  317.000000                   302.000000
# 25%                  386.000000                   386.000000
# ...

# %%
#Drop the rows where at least one element is missing
scores.dropna()
# Out:
#     School ID                                        School Name    Borough  \
# 2      01M539  New Explorations into Science, Technology and ...  Manhattan
# 3      02M294                               Essex Street Academy  Manhattan
# 4      02M308                       Lower Manhattan Arts Academy  Manhattan
# 5      02M545    High School for Dual Language and Asian Studies  Manhattan
# 6      01M292      Henry Street School for International Studies  Manhattan
# 7      01M696                     Bard High School Early College  Manhattan
# 8      02M305       Urban Assembly Academy of Government and Law  Manhattan
# 9      01M509                            Marta Valle High School  Manhattan
# 10     01M448                University Neighborhood High School  Manhattan
# 11     02M543                             New Design High School  Manhattan
# 12     02M298                                   Pace High School  Manhattan
# ...

# %%
#Remove columns that do not affect the dependent variable
del scores['School ID']
del scores['School Name']
del scores['Building Code']
del scores['Street Address']
del scores['Latitude']
del scores['Longitude']
del scores['Start Time']
del scores['End Time']

# %%
scores.head()
# Out:
#      Borough       City State  Zip Code    Phone Number  Student Enrollment  \
# 0  Manhattan  Manhattan    NY     10001    212-695-9114                 NaN
# 1  Manhattan  Manhattan    NY     10002  718-935-3660                  87.0
# 2  Manhattan  Manhattan    NY     10002    212-677-5190              1735.0
# 3  Manhattan  Manhattan    NY     10002    212-475-4773               358.0
# 4  Manhattan  Manhattan    NY     10002    212-505-0143               383.0
#
#   Percent White Percent Black Percent Hispanic Percent Asian  \
# 0           NaN           NaN              NaN           NaN
# 1         3.40%        21.80%           67.80%         4.60%
# 2        28.60%        13.30%           18.00%        38.50%
# 3        11.70%        38.50%           41.30%         5.90%
# 4         3.10%        28.20%           56.90%         8.60%
#
#    Average Score (SAT Math)  Average Score (SAT Reading)  \
# 0                       NaN                          NaN
# ...

# %%
scores1 = scores.dropna()

# %%
scores1.head()
# Out:
#      Borough       City State  Zip Code  Phone Number  Student Enrollment  \
# 2  Manhattan  Manhattan    NY     10002  212-677-5190              1735.0
# 3  Manhattan  Manhattan    NY     10002  212-475-4773               358.0
# 4  Manhattan  Manhattan    NY     10002  212-505-0143               383.0
# 5  Manhattan  Manhattan    NY     10002  212-475-4097               416.0
# 6  Manhattan  Manhattan    NY     10002  212-406-9411               255.0
#
#   Percent White Percent Black Percent Hispanic Percent Asian  \
# 2        28.60%        13.30%           18.00%        38.50%
# 3        11.70%        38.50%           41.30%         5.90%
# 4         3.10%        28.20%           56.90%         8.60%
# 5         1.70%         3.10%            5.50%        88.90%
# 6         3.90%        24.40%           56.60%        13.20%
#
#    Average Score (SAT Math)  Average Score (SAT Reading)  \
# 2                     657.0                        601.0
# ...

# %%
del scores1['Phone Number']

# %%
scores1.head()
# Out:
#      Borough       City State  Zip Code  Student Enrollment Percent White  \
# 2  Manhattan  Manhattan    NY     10002              1735.0        28.60%
# 3  Manhattan  Manhattan    NY     10002               358.0        11.70%
# 4  Manhattan  Manhattan    NY     10002               383.0         3.10%
# 5  Manhattan  Manhattan    NY     10002               416.0         1.70%
# 6  Manhattan  Manhattan    NY     10002               255.0         3.90%
#
#   Percent Black Percent Hispanic Percent Asian  Average Score (SAT Math)  \
# 2        13.30%           18.00%        38.50%                     657.0
# 3        38.50%           41.30%         5.90%                     395.0
# 4        28.20%           56.90%         8.60%                     418.0
# 5         3.10%            5.50%        88.90%                     613.0
# 6        24.40%           56.60%        13.20%                     410.0
#
#    Average Score (SAT Reading)  Average Score (SAT Writing) Percent Tested
# ...

# %%
#All the schools listed are in NY, remove that column
del scores1['State']

# %%
#Convert specific columns to categorical data type
for col in ['Borough', 'City', 'Zip Code']:
    scores1[col] = scores1[col].astype('category')
# Out:
# C:\Users\emman\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
scores1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 375 entries, 2 to 434
# Data columns (total 12 columns):
# Borough                        375 non-null category
# City                           375 non-null category
# Zip Code                       375 non-null category
# Student Enrollment             375 non-null float64
# Percent White                  375 non-null object
# Percent Black                  375 non-null object
# Percent Hispanic               375 non-null object
# Percent Asian                  375 non-null object
# Average Score (SAT Math)       375 non-null float64
# Average Score (SAT Reading)    375 non-null float64
# Average Score (SAT Writing)    375 non-null float64
# Percent Tested                 375 non-null object
# dtypes: category(3), float64(4), object(5)
# memory usage: 37.3+ KB

# %%
#Convert all percentages into decimals
scores1['Percent White'] = scores1['Percent White'].str.rstrip('%').astype('float')/100.0
# Out:
# C:\Users\emman\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
scores1['Percent Black'] = scores1['Percent Black'].str.rstrip('%').astype('float')/100.0
scores1['Percent Hispanic'] = scores1['Percent Hispanic'].str.rstrip('%').astype('float')/100.0
scores1['Percent Asian'] = scores1['Percent Asian'].str.rstrip('%').astype('float')/100.0
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-7367e430eb99> in <module>()
# ----> 1 scores1['Percent Black'] = scores1['Percent Black'].str.rstrip('%').astype('float')/100.0
#       2 scores1['Percent Hispanic'] = scores1['Percent Hispanic'].str.rstrip('%').astype('float')/100.0
#       3 scores1['Percent Asian'] = scores1['Percent Asian'].str.rstrip('%').astype('float')/100.0
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4366         if (name in self._internal_names_set or name in self._metadata or
#    4367                 name in self._accessors):
# -> 4368             return object.__getattribute__(self, name)
#    4369         else:
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
# ...

# %%
scores1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 375 entries, 2 to 434
# Data columns (total 12 columns):
# Borough                        375 non-null category
# City                           375 non-null category
# Zip Code                       375 non-null category
# Student Enrollment             375 non-null float64
# Percent White                  375 non-null float64
# Percent Black                  375 non-null float64
# Percent Hispanic               375 non-null float64
# Percent Asian                  375 non-null float64
# Average Score (SAT Math)       375 non-null float64
# Average Score (SAT Reading)    375 non-null float64
# Average Score (SAT Writing)    375 non-null float64
# Percent Tested                 375 non-null object
# dtypes: category(3), float64(8), object(1)
# memory usage: 37.3+ KB

# %%
scores1['Percent Tested'] = scores1['Percent Tested'].str.rstrip('%').astype('float')/100.0
# Out:
# C:\Users\emman\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
scores1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 375 entries, 2 to 434
# Data columns (total 12 columns):
# Borough                        375 non-null category
# City                           375 non-null category
# Zip Code                       375 non-null category
# Student Enrollment             375 non-null float64
# Percent White                  375 non-null float64
# Percent Black                  375 non-null float64
# Percent Hispanic               375 non-null float64
# Percent Asian                  375 non-null float64
# Average Score (SAT Math)       375 non-null float64
# Average Score (SAT Reading)    375 non-null float64
# Average Score (SAT Writing)    375 non-null float64
# Percent Tested                 375 non-null float64
# dtypes: category(3), float64(9)
# memory usage: 37.3 KB

# %%
scores1.describe()
# Out:
#        Student Enrollment  Percent White  Percent Black  Percent Hispanic  \
# count          375.000000     375.000000     375.000000        375.000000
# mean           764.682667       0.085819       0.353184          0.439027
# std            789.476208       0.133873       0.253682          0.244684
# min            142.000000       0.000000       0.000000          0.026000
# 25%            397.500000       0.013000       0.161500          0.209500
# 50%            483.000000       0.026000       0.287000          0.453000
# 75%            663.500000       0.094000       0.501000          0.633500
# max           5447.000000       0.799000       0.912000          1.000000
#
#        Percent Asian  Average Score (SAT Math)  Average Score (SAT Reading)  \
# count     375.000000                375.000000                   375.000000
# mean        0.104504                432.944000                   424.504000
# ...

# %%
#### Looking at the stats above, 
##the avg number of student enrolled is ~765, the smallest school is 142 and the largest school is 5447
##the avg percent if white students is 8.5%, for black 35%, Hispanic 44%, and Asain 10.4%
##avg SAT math score, 433
##avg SAT reading score, 424
##avg SAT writing score, 418

# %%
#EDA
import pandas as pd
import matplotlib.pyplot as plt

# %%
header = scores1.dtypes.index
print(header)
# Out:
# Index(['Borough', 'City', 'Zip Code', 'Student Enrollment', 'Percent White',
#        'Percent Black', 'Percent Hispanic', 'Percent Asian',
#        'Average Score (SAT Math)', 'Average Score (SAT Reading)',
#        'Average Score (SAT Writing)', 'Percent Tested'],
#       dtype='object')

# %%
corrMat = scores1.corr()
print(corrMat)
# Out:
#                              Student Enrollment  Percent White  Percent Black  \
# Student Enrollment                     1.000000       0.380273      -0.279215
# Percent White                          0.380273       1.000000      -0.422246
# Percent Black                         -0.279215      -0.422246       1.000000
# Percent Hispanic                      -0.197558      -0.334454      -0.560959
# Percent Asian                          0.471037       0.356143      -0.416148
# Average Score (SAT Math)               0.445126       0.600303      -0.379377
# Average Score (SAT Reading)            0.359782       0.615083      -0.239127
# Average Score (SAT Writing)            0.361712       0.625016      -0.267932
# Percent Tested                         0.127235       0.374962      -0.211026
#
#                              Percent Hispanic  Percent Asian  \
# Student Enrollment                  -0.197558       0.471037
# Percent White                       -0.334454       0.356143
# ...

# %%
plt.plot(scores1['Student Enrollment'])
plt.show()

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
scores1.groupby('Borough')['Borough'].count()
# Out:
# Borough
# Bronx             98
# Brooklyn         109
# Manhattan         89
# Queens            69
# Staten Island     10
# Name: Borough, dtype: int64

# %%
#Brooklyn has the great number of schools represented in the dataset at 109 schools
#Staten ISland has the lowest number at 10

# %%
scores1.groupby('Zip Code')['Zip Code'].count()
# Out:
# Zip Code
# 10002    11
# 10003     5
# 10004     4
# 10006     2
# 10009     1
# 10010     3
# 10011     6
# 10013     2
# 10016     2
# 10019     9
# 10021     1
# 10023     7
# 10024     3
# 10026     2
# 10027     3
# 10029     5
# 10030     2
# 10031     2
# 10032     2
# 10033     1
# 10035     1
# 10036     3
# 10038     1
# 10039     1
# 10040     5
# 10065     3
# 10128     1
# 10282     1
# 10301     3
# 10302     1
#          ..
# 11235     3
# 11236     7
# 11237     4
# 11238     1
# 11354     1
# 11355     2
# 11358     1
# 11361     1
# 11364     1
# 11365     1
# 11366     2
# 11367     2
# 11368     1
# 11373     4
# 11375     2
# 11385     1
# 11411     2
# 11412     1
# 11413     4
# 11416     1
# 11417     2
# 11418     1
# 11423     1
# 11426     1
# 11427     1
# 11432     8
# 11433     2
# 11434     2
# 11691     3
# 11694     4
# Name: Zip Code, Length: 115, dtype: int64

# %%
g = sns.factorplot('Borough', data=scores1, hue='Average Score (SAT Math)', kind='count', aspect=1.75)
g.set_xlabels('Borough')

# %%
#Rearrange columns so that the dependent varaible, avg math score, is at the end
scores1 = scores1[['Borough', 'City', 'Zip Code', 'Student Enrollment', 'Percent White', 'Percent Black', 'Percent Hispanic',
                  'Percent Asian', 'Average Score (SAT Reading)', 'Average Score (SAT Writing)',
                  'Percent Tested', 'Average Score (SAT Math)']]

# %%
header = scores1.dtypes.index
print(header)
# Out:
# Index(['Borough', 'City', 'Zip Code', 'Student Enrollment', 'Percent White',
#        'Percent Black', 'Percent Hispanic', 'Percent Asian',
#        'Average Score (SAT Reading)', 'Average Score (SAT Writing)',
#        'Percent Tested', 'Average Score (SAT Math)'],
#       dtype='object')

# %%
scores1.head()
# Out:
#      Borough       City Zip Code  Student Enrollment  Percent White  \
# 2  Manhattan  Manhattan    10002              1735.0          0.286
# 3  Manhattan  Manhattan    10002               358.0          0.117
# 4  Manhattan  Manhattan    10002               383.0          0.031
# 5  Manhattan  Manhattan    10002               416.0          0.017
# 6  Manhattan  Manhattan    10002               255.0          0.039
#
#    Percent Black  Percent Hispanic  Percent Asian  \
# 2          0.133             0.180          0.385
# 3          0.385             0.413          0.059
# 4          0.282             0.569          0.086
# 5          0.031             0.055          0.889
# 6          0.244             0.566          0.132
#
#    Average Score (SAT Reading)  Average Score (SAT Writing)  Percent Tested  \
# 2                        601.0                        601.0           0.910
# 3                        411.0                        387.0           0.789
# ...

# %%
del scores1['Borough']
del scores1['City']
del scores1['Zip Code']

# %%
scores1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 375 entries, 2 to 434
# Data columns (total 9 columns):
# Student Enrollment             375 non-null float64
# Percent White                  375 non-null float64
# Percent Black                  375 non-null float64
# Percent Hispanic               375 non-null float64
# Percent Asian                  375 non-null float64
# Average Score (SAT Reading)    375 non-null float64
# Average Score (SAT Writing)    375 non-null float64
# Percent Tested                 375 non-null float64
# Average Score (SAT Math)       375 non-null float64
# dtypes: float64(9)
# memory usage: 39.3 KB

# %%
scores1.head()
# Out:
#    Student Enrollment  Percent White  Percent Black  Percent Hispanic  \
# 2              1735.0          0.286          0.133             0.180
# 3               358.0          0.117          0.385             0.413
# 4               383.0          0.031          0.282             0.569
# 5               416.0          0.017          0.031             0.055
# 6               255.0          0.039          0.244             0.566
#
#    Percent Asian  Average Score (SAT Reading)  Average Score (SAT Writing)  \
# 2          0.385                        601.0                        601.0
# 3          0.059                        411.0                        387.0
# 4          0.086                        428.0                        415.0
# 5          0.889                        453.0                        463.0
# 6          0.132                        406.0                        381.0
#
#    Percent Tested  Average Score (SAT Math)
# 2           0.910                     657.0
# ...

# %%
#features
features = scores1.iloc[:,0:8]
print('Summary of feature sample')
features.head()
# Out:
# Summary of feature sample
#    Student Enrollment  Percent White  Percent Black  Percent Hispanic  \
# 2              1735.0          0.286          0.133             0.180
# 3               358.0          0.117          0.385             0.413
# 4               383.0          0.031          0.282             0.569
# 5               416.0          0.017          0.031             0.055
# 6               255.0          0.039          0.244             0.566
#
#    Percent Asian  Average Score (SAT Reading)  Average Score (SAT Writing)  \
# 2          0.385                        601.0                        601.0
# 3          0.059                        411.0                        387.0
# 4          0.086                        428.0                        415.0
# 5          0.889                        453.0                        463.0
# 6          0.132                        406.0                        381.0
#
#    Percent Tested
# 2           0.910
# 3           0.789
# ...

# %%
#dependent variable
depVar = scores1['Average Score (SAT Math)']

# %%
#Training Set (Feature Space: X Training)
X_train = (features[: 263])
X_train.head()
# Out:
#    Student Enrollment  Percent White  Percent Black  Percent Hispanic  \
# 2              1735.0          0.286          0.133             0.180
# 3               358.0          0.117          0.385             0.413
# 4               383.0          0.031          0.282             0.569
# 5               416.0          0.017          0.031             0.055
# 6               255.0          0.039          0.244             0.566
#
#    Percent Asian  Average Score (SAT Reading)  Average Score (SAT Writing)  \
# 2          0.385                        601.0                        601.0
# 3          0.059                        411.0                        387.0
# 4          0.086                        428.0                        415.0
# 5          0.889                        453.0                        463.0
# 6          0.132                        406.0                        381.0
#
#    Percent Tested
# 2           0.910
# 3           0.789
# 4           0.651
# ...

# %%
#Dependent Variable Training Set (y Training)
Y_train = depVar[: 263]
Y_train_count = len(Y_train.index)
print('The number of observations in the Y training set are:',str(Y_train_count))
Y_train.head()
# Out:
# The number of observations in the Y training set are: 263
# 2    657.0
# 3    395.0
# 4    418.0
# 5    613.0
# 6    410.0
# Name: Average Score (SAT Math), dtype: float64

# %%
#Testing Set (X Testing)
X_test = features[-112:]
X_test_count = len(X_test.index)
print('The number of observations in the feature testing set is:',str(X_test_count))
print(X_test.head())
# Out:
# The number of observations in the feature testing set is: 112
#      Student Enrollment  Percent White  Percent Black  Percent Hispanic  \
# 307               390.0          0.006          0.830             0.157
# 308               438.0          0.007          0.856             0.091
# 309               373.0          0.008          0.855             0.088
# 310               648.0          0.017          0.872             0.086
# 312               290.0          0.055          0.724             0.169
#
#      Percent Asian  Average Score (SAT Reading)  Average Score (SAT Writing)  \
# 307          0.003                        399.0                        412.0
# 308          0.030                        442.0                        410.0
# 309          0.016                        405.0                        396.0
# 310          0.009                        392.0                        394.0
# 312          0.038                        374.0                        361.0
#
# ...

# %%
#Ground Truth (y_test) 
Y_test = depVar[-112:]
Y_test_count = len(Y_test.index)
print('The number of observations in the Y training set are:',str(Y_test_count))
Y_test.head()
# Out:
# The number of observations in the Y training set are: 112
# 307    394.0
# 308    446.0
# 309    406.0
# 310    399.0
# 312    367.0
# Name: Average Score (SAT Math), dtype: float64

# %%
from sklearn.cross_validation import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_train, Y_train)
X_train.shape, X_test.shape
# Out:
# ((197, 8), (66, 8))

# %%
#imports
#numpy,pandas,scipy, math, matplotlib
import numpy as np
import pandas as pd
import scipy
from math import sqrt
import matplotlib.pyplot as plt

# %%
#estimators
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn import linear_model

# %%
#model metrics
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score

# %%
#cross validation
from sklearn.cross_validation import train_test_split

# %%
#Models
modelSVR = SVR()
modelRF = RandomForestRegressor()
modelLR = LinearRegression()

# %%
scores1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 375 entries, 2 to 434
# Data columns (total 9 columns):
# Student Enrollment             375 non-null float64
# Percent White                  375 non-null float64
# Percent Black                  375 non-null float64
# Percent Hispanic               375 non-null float64
# Percent Asian                  375 non-null float64
# Average Score (SAT Reading)    375 non-null float64
# Average Score (SAT Writing)    375 non-null float64
# Percent Tested                 375 non-null float64
# Average Score (SAT Math)       375 non-null float64
# dtypes: float64(9)
# memory usage: 39.3 KB

# %%
modelRF.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
modelSVR.fit(X_train, Y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
modelLR.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print(cross_val_score(modelRF, X_train, Y_train))
# Out:
# [0.94144374 0.95496375 0.71475875]

# %%
print(cross_val_score(modelSVR, X_train, Y_train))
# Out:
# [-0.14560561 -0.01297801 -0.08301111]

# %%
print(cross_val_score(modelLR, X_train, Y_train))
# Out:
# [0.95170437 0.97700936 0.84550856]

# %%
#RF and LR have good scores
#SVR has low scores showing that it might be a worse performing model

# %%
#Model Fitting - Random Forest
modelRF.fit(X_train, Y_train)
print(cross_val_score(modelRF, X_train, Y_train))
modelRF.score(X_train, Y_train)
# Out:
# [0.92818369 0.95924122 0.75607829]
# 0.9860370163716617

# %%
#Model Fitting - Support Vector Regression
modelSVR.fit(X_train, Y_train)
print(cross_val_score(modelSVR, X_train, Y_train)) 
modelSVR.score(X_train, Y_train)
# Out:
# [-0.14560561 -0.01297801 -0.08301111]
# -0.06052025628126345

# %%
#Model Fitting - Logistic Regression
modelLR.fit(X_train, Y_train)
print(cross_val_score(modelLR, X_train, Y_train)) 
modelLR.score(X_train, Y_train)
# Out:
# [0.95170437 0.97700936 0.84550856]
# 0.9538103604572647

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from math import sqrt

# %%
#Make Predictions - RF
predictionsRF = modelRF.predict(X_test)
predRsquaredRF = r2_score(Y_test, predictionsRF)
rmseRF = sqrt(mean_squared_error(Y_test, predictionsRF))
print('R Squared RF: %.3f' % predRsquaredRF)
print('RMSE RF: %.3f' % rmseRF)
# Out:
# R Squared RF: 0.885
# RMSE RF: 24.736

# %%
#Make Predictions - SVR
predictionsSVR = modelSVR.predict(X_test)
predRsquaredSVR = r2_score(Y_test, predictionsSVR)
rmseSVR = sqrt(mean_squared_error(Y_test, predictionsSVR))
print('R Squared SVR: %.3f' % predRsquaredSVR)
print('RMSE SVR: %.3f' % rmseSVR)
# Out:
# R Squared SVR: -0.169
# RMSE SVR: 78.753

# %%
#Make Predictions - LR
predictionsLR = modelLR.predict(X_test)
predRsquaredLR = r2_score(Y_test, predictionsLR)
rmseLR = sqrt(mean_squared_error(Y_test, predictionsLR))
print('R Squared LR: %.3f' % predRsquaredLR)
print('RMSE LR: %.3f' % rmseLR)
# Out:
# R Squared LR: 0.943
# RMSE LR: 17.330

# %%
#Plotting the results - RF
plt.scatter(Y_test, predictionsRF, color=['blue','green'], alpha = 0.5)
plt.xlabel('Ground Truth')
plt.ylabel('Predictions')
plt.show();

# %%
#Plotting the results - SVR
plt.scatter(Y_test, predictionsSVR, color=['blue','green'], alpha = 0.5)
plt.xlabel('Ground Truth')
plt.ylabel('Predictions')
plt.show();

# %%
#Plotting the results - LR
plt.scatter(Y_test, predictionsLR, color=['blue','green'], alpha = 0.5)
plt.xlabel('Ground Truth')
plt.ylabel('Predictions')
plt.show();

# %%
#From the graphs above, it's clear that the logistic regression is the top performing model

# %%
#Now going to tune RF and LR to see if we can get better R sqaured and RMSE scores

# %%
#Model Tuning - RF
#Models
modelRF2 = RandomForestRegressor(n_estimators = 15)

#Model Fitting - Random Forest 2 
modelRF2.fit(X_train, Y_train)
print(cross_val_score(modelRF2, X_train, Y_train))
modelRF2.score(X_train, Y_train)

#Make Predictions - RF 2 
predictionsRF2 = modelRF2.predict(X_test)
predRsquaredRF2 = r2_score(Y_test, predictionsRF2)
rmseRF2 = sqrt(mean_squared_error(Y_test, predictionsRF2))
print('R Squared RF2: %.3f' % predRsquaredRF2)
print('RMSE RF2: %.3f' % rmseRF2)

#Plotting the results - RF 2 
plt.scatter(Y_test, predictionsRF2, color=['blue','green'], alpha = 0.5)
plt.xlabel('Ground Truth')
plt.ylabel('Predictions')
plt.show();
# Out:
# [0.94884966 0.95646206 0.73514841]
# R Squared RF2: 0.878
# RMSE RF2: 25.401

# %%
modelRF3 = RandomForestRegressor(n_estimators =5)

modelRF3.fit(X_train, Y_train)
print(cross_val_score(modelRF3, X_train, Y_train))
modelRF3.score(X_train, Y_train)

predictionsRF3 = modelRF3.predict(X_test)
predRsquaredRF3 = r2_score(Y_test, predictionsRF3)
rmseRF3 = sqrt(mean_squared_error(Y_test, predictionsRF3))
print('R Squared RF3: %.3f' % predRsquaredRF3)
print('RMSE RF3: %.3f' % rmseRF3)

plt.scatter(Y_test, predictionsRF3, color=['blue','green'], alpha = 0.5)
plt.xlabel('Ground Truth')
plt.ylabel('Predictions')
plt.show();
# Out:
# [0.91665263 0.94203324 0.70828318]
# R Squared RF3: 0.877
# RMSE RF3: 25.542

# %%
#Model Tuning - LR
#Models
modelLR2 = LinearRegression(normalize = True)

#Model Fitting - LR 2
modelLR2.fit(X_train, Y_train)
print(cross_val_score(modelLR2, X_train, Y_train))
modelLR2.score(X_train, Y_train)

#Make Predictions - LR 2 
predictionsLR2 = modelLR2.predict(X_test)
predRsquaredLR2 = r2_score(Y_test, predictionsLR2)
rmseLR2 = sqrt(mean_squared_error(Y_test, predictionsLR2))
print('R Squared LR2: %.3f' % predRsquaredLR2)
print('RMSE LR2: %.3f' % rmseLR2)

#Plotting the results - LR 2 
plt.scatter(Y_test, predictionsLR2, color=['blue','green'], alpha = 0.5)
plt.xlabel('Ground Truth')
plt.ylabel('Predictions')
plt.show();
# Out:
# [0.95170437 0.97700936 0.84550856]
# R Squared LR2: 0.943
# RMSE LR2: 17.330

# %%
#Model Tuning - LR
#Models
modelLR3 = LinearRegression(fit_intercept = False)

#Model Fitting - LR 3
modelLR3.fit(X_train, Y_train)
print(cross_val_score(modelLR3, X_train, Y_train))
modelLR3.score(X_train, Y_train)

#Make Predictions - LR 3
predictionsLR3 = modelLR3.predict(X_test)
predRsquaredLR3 = r2_score(Y_test, predictionsLR3)
rmseLR3 = sqrt(mean_squared_error(Y_test, predictionsLR3))
print('R Squared LR3: %.3f' % predRsquaredLR3)
print('RMSE LR3: %.3f' % rmseLR3)

#Plotting the results - LR 3 
plt.scatter(Y_test, predictionsLR3, color=['blue','green'], alpha = 0.5)
plt.xlabel('Ground Truth')
plt.ylabel('Predictions')
plt.show();
# Out:
# [0.95478887 0.97548376 0.84270938]
# R Squared LR3: 0.945
# RMSE LR3: 17.006

# %%
#Best r sqaured and rmse scores found with linear regression and fit_intercept set to false
